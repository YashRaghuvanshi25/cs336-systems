# %%
import torch
torch.cuda.is_available(), torch.cuda.get_device_name(0), torch.__version__
# Out:
# (True, 'Tesla T4', '2.9.0+cu128')

# %%
# %pip install -e "./cs336-basics" -e "." --no-deps
# Out:
# Obtaining file:///content/cs336-systems/cs336-basics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Obtaining file:///content/cs336-systems
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for cs336_basics (pyproject.toml) ... done
#   Created wheel for cs336_basics: filename=cs336_basics-1.0.3-0.editable-py3-none-any.whl size=3165 sha256=ae9db95334b1fe80eb197a529927c1cdd858206e8dccec906ac8db4dbe070294
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uqg3o25g/wheels/99/a5/d4/ee829cf4d4e77167ed9928b028b79641a8c4f931649c70562f
#   Building editable for cs336-systems (pyproject.toml) ... done
# ...

# %%
import cs336_basics
import cs336_systems
print("Environment ready")
# Out:
# Environment ready

# %%
# %cd cs336-systems
# !git pull
# Out:
# /content/cs336-systems
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 1), reused 7 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 6.26 KiB | 3.13 MiB/s, done.
# From https://github.com/YashRaghuvanshi25/cs336-systems
#    51e2b9a..4078e3d  main       -> origin/main
# Updating 51e2b9a..4078e3d
# Fast-forward
#  .vscode/settings.json         |   5 +
#  cs336_systems/benchmarking.py | 101 +++++++++++
#  dev.ipynb                     | 414 +++++++++++++++++++++++++++++++++++++++++-
#  3 files changed, 511 insertions(+), 9 deletions(-)
#  create mode 100644 .vscode/settings.json
#  create mode 100644 cs336_systems/benchmarking.py

# %%
# !python cs336_systems/benchmarking.py
# Out:
# FP32 Forward + Backward:
# Traceback (most recent call last):
#   File "/content/cs336-systems/cs336_systems/benchmarking.py", line 92, in <module>
#     benchmark_model()
#   File "/content/cs336-systems/cs336_systems/benchmarking.py", line 22, in benchmark_model
#     model = BasicsTransformerLM(
#             ^^^^^^^^^^^^^^^^^^^^
# TypeError: BasicsTransformerLM.__init__() got an unexpected keyword argument 'n_layers'

# %%
# %cd cs336-systems
# !git pull
# !python cs336_systems/benchmarking.py
# Out:
# [Errno 2] No such file or directory: 'cs336-systems'
# /content/cs336-systems
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 5 (delta 3), reused 5 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 1.43 KiB | 731.00 KiB/s, done.
# From https://github.com/YashRaghuvanshi25/cs336-systems
#    4078e3d..d8c73ea  main       -> origin/main
# Updating 4078e3d..d8c73ea
# Fast-forward
#  cs336_systems/benchmarking.py | 11 +++---
#  dev.ipynb                     | 80 +++++++++++++++++++++++++++++++++++++++++++
#  2 files changed, 87 insertions(+), 4 deletions(-)
# FP32 Forward + Backward:
# /content/cs336-systems/cs336_systems/benchmarking.py:48: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# ...

# %%
# %cd /content/cs336-systems
from cs336_systems.benchmarking import benchmark_model
benchmark_model(batch_size=16, seq_len=512)
benchmark_model(batch_size=16, seq_len=512, use_amp=True)
# Out:
# /content/cs336-systems
# /content/cs336-systems/cs336_systems/benchmarking.py:48: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# /content/cs336-systems/cs336_systems/benchmarking.py:56: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# /content/cs336-systems/cs336_systems/benchmarking.py:75: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# Average step time: 0.599722 seconds
# Average step time: 0.299755 seconds
# 0.2997549533843994
