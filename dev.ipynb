# %%
import torch
torch.cuda.is_available(), torch.cuda.get_device_name(0), torch.__version__
# Out:
# (True, 'Tesla T4', '2.9.0+cu128')

# %%
# !nvidia-smi

import os

if not os.path.exists("cs336-systems"):
    # !git clone https://github.com/YashRaghuvanshi25/cs336-systems.git
else:
    # %cd cs336-systems
    # !git pull
    # %cd ..

# %cd cs336-systems

# !pip install -e ./cs336-basics --no-deps
# !pip install -e . --no-deps

print("✅ Environment Ready")
# Out:
# Mon Feb 16 14:53:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8              9W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# %cd /content/cs336-systems
# !python cs336_systems/attention_benchmark.py
# Out:
# /content/cs336-systems
# /content/cs336-systems/cs336_systems/attention_benchmark.py:21: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# /content/cs336-systems/cs336_systems/attention_benchmark.py:25: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# /content/cs336-systems/cs336_systems/attention_benchmark.py:34: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# Seq Len 128 → 0.000226 seconds
# Seq Len 256 → 0.000759 seconds
# Seq Len 512 → 0.002077 seconds
# Seq Len 1024 → 0.005945 seconds
