# %%
# %cd /content/cs336-systems
# !pip install -e ./cs336-basics
# Out:
# /content/cs336-systems
# Obtaining file:///content/cs336-systems/cs336-basics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: einops>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from cs336_basics==1.0.3) (0.8.2)
# Collecting einx>=0.3.0 (from cs336_basics==1.0.3)
#   Downloading einx-0.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting jaxtyping>=0.3.0 (from cs336_basics==1.0.3)
#   Downloading jaxtyping-0.3.8-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from cs336_basics==1.0.3) (2.0.2)
# Collecting psutil>=6.1.1 (from cs336_basics==1.0.3)
#   Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: pytest>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from cs336_basics==1.0.3) (8.4.2)
# Requirement already satisfied: regex>=2024.11.6 in /usr/local/lib/python3.12/dist-packages (from cs336_basics==1.0.3) (2025.11.3)
# Collecting submitit>=1.5.2 (from cs336_basics==1.0.3)
#   Downloading submitit-1.5.4-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: tiktoken>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from cs336_basics==1.0.3) (0.12.0)
# Collecting torch~=2.6.0 (from cs336_basics==1.0.3)
#   Downloading torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl.metadata (28 kB)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from cs336_basics==1.0.3) (4.67.3)
# Requirement already satisfied: wandb>=0.19.7 in /usr/local/lib/python3.12/dist-packages (from cs336_basics==1.0.3) (0.24.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from einx>=0.3.0->cs336_basics==1.0.3) (1.14.0)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from einx>=0.3.0->cs336_basics==1.0.3) (2.4.7)
# Collecting wadler-lindig>=0.1.3 (from jaxtyping>=0.3.0->cs336_basics==1.0.3)
#   Downloading wadler_lindig-0.1.7-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.3.4->cs336_basics==1.0.3) (2.3.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.3.4->cs336_basics==1.0.3) (26.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.3.4->cs336_basics==1.0.3) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.3.4->cs336_basics==1.0.3) (2.19.2)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from submitit>=1.5.2->cs336_basics==1.0.3) (3.1.2)
# Requirement already satisfied: typing_extensions>=3.7.4.2 in /usr/local/lib/python3.12/dist-packages (from submitit>=1.5.2->cs336_basics==1.0.3) (4.15.0)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken>=0.9.0->cs336_basics==1.0.3) (2.32.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336_basics==1.0.3) (3.20.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336_basics==1.0.3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336_basics==1.0.3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336_basics==1.0.3) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch~=2.6.0->cs336_basics==1.0.3)
#   Downloading triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336_basics==1.0.3) (75.2.0)
# Collecting sympy (from einx>=0.3.0->cs336_basics==1.0.3)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->einx>=0.3.0->cs336_basics==1.0.3) (1.3.0)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336_basics==1.0.3) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336_basics==1.0.3) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336_basics==1.0.3) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336_basics==1.0.3) (5.29.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336_basics==1.0.3) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336_basics==1.0.3) (6.0.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336_basics==1.0.3) (2.52.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.19.7->cs336_basics==1.0.3) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.19.7->cs336_basics==1.0.3) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.19.7->cs336_basics==1.0.3) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.19.7->cs336_basics==1.0.3) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.9.0->cs336_basics==1.0.3) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.9.0->cs336_basics==1.0.3) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.9.0->cs336_basics==1.0.3) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken>=0.9.0->cs336_basics==1.0.3) (2026.1.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch~=2.6.0->cs336_basics==1.0.3) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.19.7->cs336_basics==1.0.3) (5.0.2)
# Downloading einx-0.3.0-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.0/103.0 kB 6.7 MB/s eta 0:00:00
# Downloading jaxtyping-0.3.8-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.2/56.2 kB 7.3 MB/s eta 0:00:00
# Downloading psutil-7.2.2-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 21.1 MB/s eta 0:00:00
# Downloading submitit-1.5.4-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 9.8 MB/s eta 0:00:00
# Downloading torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl (766.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 766.6/766.6 MB 838.1 kB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.7 MB/s eta 0:00:0000:010:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 85.8 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 69.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 6.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.7 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 12.8 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 105.6 MB/s eta 0:00:00a 0:00:01
# Downloading triton-3.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (253.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.2/253.2 MB 4.9 MB/s eta 0:00:00:00:0100:01
# Downloading wadler_lindig-0.1.7-py3-none-any.whl (20 kB)
# Building wheels for collected packages: cs336_basics
#   Building editable for cs336_basics (pyproject.toml) ... done
#   Created wheel for cs336_basics: filename=cs336_basics-1.0.3-0.editable-py3-none-any.whl size=3165 sha256=9d9777fa404062dac54405992ddfbd64d5fffeb982dfb282967606f8210e4f2b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pvqb56hq/wheels/99/a5/d4/ee829cf4d4e77167ed9928b028b79641a8c4f931649c70562f
# Successfully built cs336_basics
# Installing collected packages: triton, nvidia-cusparselt-cu12, wadler-lindig, sympy, submitit, psutil, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jaxtyping, einx, nvidia-cusolver-cu12, torch, cs336_basics
#   Attempting uninstall: triton
#     Found existing installation: triton 3.5.0
#     Uninstalling triton-3.5.0:
#       Successfully uninstalled triton-3.5.0
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.5
#     Uninstalling psutil-5.9.5:
#       Successfully uninstalled psutil-5.9.5
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.8.90
#     Uninstalling nvidia-nvtx-cu12-12.8.90:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.27.5
#     Uninstalling nvidia-nccl-cu12-2.27.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.27.5
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.10.2.21
#     Uninstalling nvidia-cudnn-cu12-9.10.2.21:
#       Successfully uninstalled nvidia-cudnn-cu12-9.10.2.21
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#   Attempting uninstall: torch
#     Found existing installation: torch 2.9.0+cu128
#     Uninstalling torch-2.9.0+cu128:
#       Successfully uninstalled torch-2.9.0+cu128
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.24.0+cu128 requires torch==2.9.0, but you have torch 2.6.0 which is incompatible.
# torchaudio 2.9.0+cu128 requires torch==2.9.0, but you have torch 2.6.0 which is incompatible.
# Successfully installed cs336_basics-1.0.3 einx-0.3.0 jaxtyping-0.3.8 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 psutil-7.2.2 submitit-1.5.4 sympy-1.13.1 torch-2.6.0 triton-3.2.0 wadler-lindig-0.1.7

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/cs336-systems
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: cs336-basics in /usr/local/lib/python3.12/dist-packages (from cs336-systems==1.0.5) (1.0.3)
# Collecting humanfriendly (from cs336-systems==1.0.5)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from cs336-systems==1.0.5) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from cs336-systems==1.0.5) (2.0.2)
# Requirement already satisfied: pytest>=8 in /usr/local/lib/python3.12/dist-packages (from cs336-systems==1.0.5) (8.4.2)
# Requirement already satisfied: regex>=2024.11.6 in /usr/local/lib/python3.12/dist-packages (from cs336-systems==1.0.5) (2025.11.3)
# Requirement already satisfied: torch~=2.6.0 in /usr/local/lib/python3.12/dist-packages (from cs336-systems==1.0.5) (2.6.0)
# Requirement already satisfied: tqdm>=4.67.1 in /usr/local/lib/python3.12/dist-packages (from cs336-systems==1.0.5) (4.67.3)
# Requirement already satisfied: wandb>=0.19.7 in /usr/local/lib/python3.12/dist-packages (from cs336-systems==1.0.5) (0.24.2)
# Requirement already satisfied: pandas>=2 in /usr/local/lib/python3.12/dist-packages (from cs336-systems==1.0.5) (2.2.2)
# Collecting ty>=0.0.1a16 (from cs336-systems==1.0.5)
#   Downloading ty-0.0.17-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->cs336-systems==1.0.5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->cs336-systems==1.0.5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2->cs336-systems==1.0.5) (2025.3)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=8->cs336-systems==1.0.5) (2.3.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from pytest>=8->cs336-systems==1.0.5) (26.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=8->cs336-systems==1.0.5) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=8->cs336-systems==1.0.5) (2.19.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (75.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->cs336-systems==1.0.5) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch~=2.6.0->cs336-systems==1.0.5) (1.3.0)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336-systems==1.0.5) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336-systems==1.0.5) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336-systems==1.0.5) (4.5.1)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336-systems==1.0.5) (5.29.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336-systems==1.0.5) (2.12.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336-systems==1.0.5) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336-systems==1.0.5) (2.32.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb>=0.19.7->cs336-systems==1.0.5) (2.52.0)
# Requirement already satisfied: einops>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from cs336-basics->cs336-systems==1.0.5) (0.8.2)
# Requirement already satisfied: einx>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from cs336-basics->cs336-systems==1.0.5) (0.3.0)
# Requirement already satisfied: jaxtyping>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from cs336-basics->cs336-systems==1.0.5) (0.3.8)
# Requirement already satisfied: psutil>=6.1.1 in /usr/local/lib/python3.12/dist-packages (from cs336-basics->cs336-systems==1.0.5) (7.2.2)
# Requirement already satisfied: submitit>=1.5.2 in /usr/local/lib/python3.12/dist-packages (from cs336-basics->cs336-systems==1.0.5) (1.5.4)
# Requirement already satisfied: tiktoken>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from cs336-basics->cs336-systems==1.0.5) (0.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cs336-systems==1.0.5) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cs336-systems==1.0.5) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cs336-systems==1.0.5) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cs336-systems==1.0.5) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cs336-systems==1.0.5) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->cs336-systems==1.0.5) (3.3.2)
# Requirement already satisfied: frozendict in /usr/local/lib/python3.12/dist-packages (from einx>=0.3.0->cs336-basics->cs336-systems==1.0.5) (2.4.7)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb>=0.19.7->cs336-systems==1.0.5) (4.0.12)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping>=0.3.0->cs336-basics->cs336-systems==1.0.5) (0.1.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.19.7->cs336-systems==1.0.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.19.7->cs336-systems==1.0.5) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->wandb>=0.19.7->cs336-systems==1.0.5) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2->cs336-systems==1.0.5) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb>=0.19.7->cs336-systems==1.0.5) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb>=0.19.7->cs336-systems==1.0.5) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb>=0.19.7->cs336-systems==1.0.5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.0.0->wandb>=0.19.7->cs336-systems==1.0.5) (2026.1.4)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from submitit>=1.5.2->cs336-basics->cs336-systems==1.0.5) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch~=2.6.0->cs336-systems==1.0.5) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.19.7->cs336-systems==1.0.5) (5.0.2)
# Downloading ty-0.0.17-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.6/10.6 MB 109.6 MB/s eta 0:00:0000:010:01
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 11.1 MB/s eta 0:00:00
# Building wheels for collected packages: cs336-systems
#   Building editable for cs336-systems (pyproject.toml) ... done
#   Created wheel for cs336-systems: filename=cs336_systems-1.0.5-py3-none-any.whl size=2448 sha256=d01b3a5b349a0ae9d16e2a7579aa9394d685ca9fc9125bb33683fca88f49ca09
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ap2qqfbv/wheels/c1/b7/cf/466e1b34aeaeb7df1644d98c854a46ac730dde245e53e6c00a
# Successfully built cs336-systems
# Installing collected packages: ty, humanfriendly, cs336-systems
# Successfully installed cs336-systems-1.0.5 humanfriendly-10.0 ty-0.0.17

# %%
import torch
torch.cuda.is_available(), torch.cuda.get_device_name(0), torch.__version__
# Out:
# (True, 'Tesla T4', '2.9.0+cu128')

# %%
# %pip install -e "./cs336-basics" -e "." --no-deps
# Out:
# Obtaining file:///content/cs336-systems/cs336-basics
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Obtaining file:///content/cs336-systems
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: cs336_basics, cs336-systems
#   Building editable for cs336_basics (pyproject.toml) ... done
#   Created wheel for cs336_basics: filename=cs336_basics-1.0.3-0.editable-py3-none-any.whl size=3165 sha256=ae9db95334b1fe80eb197a529927c1cdd858206e8dccec906ac8db4dbe070294
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uqg3o25g/wheels/99/a5/d4/ee829cf4d4e77167ed9928b028b79641a8c4f931649c70562f
#   Building editable for cs336-systems (pyproject.toml) ... done
#   Created wheel for cs336-systems: filename=cs336_systems-1.0.5-py3-none-any.whl size=2448 sha256=d01b3a5b349a0ae9d16e2a7579aa9394d685ca9fc9125bb33683fca88f49ca09
#   Stored in directory: /tmp/pip-ephem-wheel-cache-uqg3o25g/wheels/c1/b7/cf/466e1b34aeaeb7df1644d98c854a46ac730dde245e53e6c00a
# Successfully built cs336_basics cs336-systems
# Installing collected packages: cs336-systems, cs336_basics
#   Attempting uninstall: cs336-systems
#     Found existing installation: cs336-systems 1.0.5
#     Uninstalling cs336-systems-1.0.5:
#       Successfully uninstalled cs336-systems-1.0.5
#   Attempting uninstall: cs336_basics
#     Found existing installation: cs336_basics 1.0.3
#     Uninstalling cs336_basics-1.0.3:
#       Successfully uninstalled cs336_basics-1.0.3
# Successfully installed cs336-systems-1.0.5 cs336_basics-1.0.3

# %%
import cs336_basics
import cs336_systems
print("Environment ready")
# Out:
# Environment ready

# %%
# %cd cs336-systems
# !git pull
# Out:
# /content/cs336-systems
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 1), reused 7 (delta 1), pack-reused 0 (from 0)
# Unpacking objects: 100% (7/7), 6.26 KiB | 3.13 MiB/s, done.
# From https://github.com/YashRaghuvanshi25/cs336-systems
#    51e2b9a..4078e3d  main       -> origin/main
# Updating 51e2b9a..4078e3d
# Fast-forward
#  .vscode/settings.json         |   5 +
#  cs336_systems/benchmarking.py | 101 +++++++++++
#  dev.ipynb                     | 414 +++++++++++++++++++++++++++++++++++++++++-
#  3 files changed, 511 insertions(+), 9 deletions(-)
#  create mode 100644 .vscode/settings.json
#  create mode 100644 cs336_systems/benchmarking.py

# %%
# !python cs336_systems/benchmarking.py
# Out:
# FP32 Forward + Backward:
# Traceback (most recent call last):
#   File "/content/cs336-systems/cs336_systems/benchmarking.py", line 92, in <module>
#     benchmark_model()
#   File "/content/cs336-systems/cs336_systems/benchmarking.py", line 22, in benchmark_model
#     model = BasicsTransformerLM(
#             ^^^^^^^^^^^^^^^^^^^^
# TypeError: BasicsTransformerLM.__init__() got an unexpected keyword argument 'n_layers'

# %%
import inspect
from cs336_basics.model import BasicsTransformerLM

print(inspect.signature(BasicsTransformerLM))
# Out:
# (vocab_size: 'int', context_length: 'int', d_model: 'int', num_layers: 'int', num_heads: 'int', d_ff: 'int', rope_theta: 'float')
